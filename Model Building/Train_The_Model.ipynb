# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=50,batch_size=64,verbose=1)
# Out:
# Epoch 1/50
# 84/84 [==============================] - 9s 42ms/step - loss: 0.0020 - val_loss: 9.8772e-04
# Epoch 2/50
# 84/84 [==============================] - 2s 25ms/step - loss: 1.3326e-04 - val_loss: 7.7793e-04
# Epoch 3/50
# 84/84 [==============================] - 2s 25ms/step - loss: 1.2542e-04 - val_loss: 9.1956e-04
# Epoch 4/50
# 84/84 [==============================] - 2s 24ms/step - loss: 1.3340e-04 - val_loss: 8.0346e-04
# Epoch 5/50
# 84/84 [==============================] - 2s 25ms/step - loss: 1.3148e-04 - val_loss: 8.3154e-04
# Epoch 6/50
# 84/84 [==============================] - 2s 25ms/step - loss: 1.2696e-04 - val_loss: 0.0011
# Epoch 7/50
# 84/84 [==============================] - 2s 24ms/step - loss: 1.2340e-04 - val_loss: 8.2451e-04
# Epoch 8/50
# 84/84 [==============================] - 2s 24ms/step - loss: 1.1732e-04 - val_loss: 7.5403e-04
# Epoch 9/50
# 84/84 [==============================] - 2s 24ms/step - loss: 1.2095e-04 - val_loss: 7.1424e-04
# ...
